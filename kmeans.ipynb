# %%
import os
import numpy as np
import rasterio
from glob import glob
from tqdm import tqdm

# %%
def load_data(base_dir):

    s1_dir=glob(base_dir+'s1_validation'+'/'+'*.tif')
    s2_dir=[]
    lc_dir=[]
    for i in tqdm(range(len(s1_dir))):
        s1_filename=os.path.basename(s1_dir[i])
        former=s1_filename.split('_s1')[0]
        ID=s1_filename.split('_s1')[1]
        s2_dir.append(base_dir+'s2_validation/'+former+'_s2'+ID)
        lc_dir.append(base_dir + 'lc_validation/' + former + '_lc' + ID)

    s1_dir=np.array(s1_dir)
    s2_dir=np.array(s2_dir)
    lc_dir=np.array(lc_dir)

    return s1_dir,s2_dir,lc_dir

def read_data(f1,f2):
    
    with rasterio.open(f1) as patch:
        x1 = patch.read(list(range(1,3)))

    with rasterio.open(f2) as patch:
        x2 = patch.read(list(range(1,14)))

    return x1,x2

def clean(x1,x2):
    # s1
    x1[np.isnan(x1)] = 0
    # s2
    x2[np.isnan(x2)] = 0

    # s1_recommend
    x1[x1<-25]=-25
    x1[x1>0]=0
    # s2_recommend
    x2[x2 < 0] = 0
    x2[x2>10000]=10000

    return x1.astype('float16'),x2.astype('float16')

def norm(x1,x2):
    # input,x1:[-25,0],x2:[0,10000]
    h,w,c1=x1.shape
    h,w,c2=x2.shape
    x2 /= 10000 * 1.0
    x1 = (x1 + 25) / 25 * 1.0
    return x1,x2

lab_dict={1:1,2:1,3:1,4:1,5:1,6:2,7:2,8:3,9:3,10:4,11:5,12:6,14:6,13:7,15:8,16:9,17:10}

def process_label(y):
    C,H,W=y.shape
    y=y[[0],:,:]#1,h,w, simplified IGBP
    y=y.reshape(-1)
    y = list(map(lambda x: lab_dict[x], y))
    y=np.array(y)#list->array
    y=y.reshape(-1,H,W)
    y-=1 # start from 0
    return y

def filter_label(x2,y):

    x2[np.isnan(x2)] = 0

    x2[x2>10000]=10000
    x2[x2<0]=0

    x2 = x2.astype('float')

    R = x2[:, :, 3]
    G = x2[:, :, 2]
    B = x2[:, :, 1]
    Nir = x2[:, :, 7]  # TM4
    Mir = x2[:, :, 10]  # TM5
    SWir = x2[:, :, 11]  # TM7

    MSI = SWir / Nir
    NDWI = (G - Nir) / (G + Nir)
    NDVI = (Nir - R) / (Nir + R)
    NDBBI = (1.5 * SWir - (Nir + G) / 2.) / (1.5 * SWir + (Nir + G) / 2.)  # 归一化差值裸地与建筑用地指数
    BSI = ((Mir + R) - (Nir + B)) / ((Mir + R) + (Nir + B))  # 裸土指数
    NBI = R * SWir / Nir

    y_clean=y.copy()

    # Forest0,Shrubland1,bg_1-2,Grassland3,Wetlands4,Croplands5,Urban6,bg2-7,Barren8,water9
    
    # columns

#     # 修正不符合要求的森林类
#     y_clean[np.where((NDVI > 0.75) & (y != 0))] = 10
#     # 修正不符合要求的灌木类
#     y_clean[np.where((NDVI > 0.2) & (NDVI < 0.35) & (MSI > 1.5) & (y != 1))] = 10
#     # 修正不符合要求的草地类
#     y_clean[np.where((NDVI > 0.4) & (NDVI < 0.55) & (y != 3))] = 10
#     # 修正不符合要求的湿地类
#     y_clean[np.where((NDVI > 0.6) & (NDVI < 0.75) & (y != 4))] = 10
#     # 修正不符合要求的农田类
#     #y_clean[np.where((NDVI > 0.2) & (NDVI < 0.35) & (MSI > 1) & (MSI < 1.5) & (y != 5))] = 10
#     # 修正不符合要求的建筑类
#     #y_clean[np.where((NDVI > 0.2) & (NDVI < 0.35) & (MSI > 0.9) & (MSI < 1) & (y != 6))] = 10
#     # 修正不符合要求的裸地类
#     y_clean[np.where((NDVI > 0) & (NDVI < 0.15) & (y != 8))] = 10
#     # 修正裸土建筑错分到其他类
#     #y_clean[np.where((BSI > -0.4) & (NDVI < 0.15) & (y != 6) & (y != 8))] = 10
#     # 修正不符合要求的水体类
#     y_clean[np.where((NDWI > 0.) & (y != 9))] = 10

#     # rows
#     # forest

#     # 修正其他类错标到森林
#     y_clean[np.where((NDVI < 0.75) & (y == 0))] = 10

#     # shrubland
    
#     # savanna

#     # 将热带草原标签修正为草地
#     #y_clean[np.where((NDVI > 0.4) & (NDVI < 0.55) & (y == 2) & (np.sum(y == 9) < 2000))] = 3
#     # 将热带草原标签修正为湿地
#     y_clean[np.where((NDVI > 0.6) & (NDVI < 0.75) & (y == 2) & (np.sum(y == 9) > 10000))] = 4
#     # 将热带草原标签修正为灌木
#     y_clean[np.where((NDVI > 0.2) & (NDVI < 0.35) & (MSI > 1.5) & (y == 2))]=1
#     # 将热带草原标签修正为裸地
#     y_clean[np.where((NBI > 750) &(NDVI<0.2)& (NDVI>0) & (y == 2))] = 8
  
#     # grassland

#     # 将草地标签修正为湿地
#     y_clean[np.where((NDVI > 0.6) & (NDVI < 0.75) & (y == 3) & (np.sum(y==9)>10000))] = 4

    # wetland
    # 将湿地修正为森林
    #y_clean[np.where((NDVI > 0.75) & (y == 4))] = 0

    y_clean[y_clean==2]=10
    y_clean[y_clean==7]=10

    return y_clean

# %% [markdown]
# ## Loading & Preparing

# %%
base_dir = '/data/PublicData/DF2020/val/'
s1_pre, s2_pre, lc_pre=load_data(base_dir)
# Out:
# 100%|██████████| 986/986 [00:00<00:00, 239702.30it/s]

# %%
s1_val=np.zeros([s1_pre.shape[0],256,256,2],dtype='float16')
s2_val=np.zeros([s1_pre.shape[0],256,256,10],dtype='float16')
y_val=np.zeros([s1_pre.shape[0],1,256,256],dtype='uint8')

# %%
for i in tqdm(range(s1_pre.shape[0])):
    s1_name=s1_pre[i]
    s2_name=s2_pre[i]
    y_name=lc_pre[i]
    x1,x2=read_data(s1_name,s2_name)
    x1=x1.transpose(1,2,0)#h,w,c
    x2=x2.transpose(1,2,0)
    x2_tmp=x2.copy()
    x2=x2[:,:,[1,2,3,4,5,6,7,10,11,12]]#remove b1,9,10
    
    x1,x2=clean(x1,x2)
    
    with rasterio.open(y_name) as patch:
        y = patch.read(list(range(1, 5)))
    y = process_label(y)
    y = filter_label(x2_tmp, y)
    x1, x2 = norm(x1, x2)
    
    s1_val[i,:,:,:]=x1
    s2_val[i,:,:,:]=x2
    y_val[i,:,:,:]=y
# Out:
# 100%|██████████| 986/986 [02:53<00:00,  5.68it/s]

# %%
np.unique(y_val)
# Out:
# array([ 0,  1,  3,  4,  5,  6,  8,  9, 10], dtype=uint8)

# %% [markdown]
# merge

# %%
s_val=np.concatenate((s1_val,s2_val),axis=3)

# %%
s_val.shape
# Out:
# (986, 256, 256, 2)

# %%
s_val=s_val.reshape(-1,s_val.shape[-1])

# %%
s_val.shape
# Out:
# (64618496, 2)

# %%
y_val=y_val.reshape(-1)

# %%
y_val.shape
# Out:
# (64618496,)

# %% [markdown]
# filter

# %%
idx=y_val!=10

# %%
s_val=s_val[idx]
y_val=y_val[idx]

# %%
s_val.shape
# Out:
# (40818077, 2)

# %% [markdown]
# ## Training

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from munkres import Munkres,print_matrix

# %%
X_trn,X_tes,y_trn,y_tes =train_test_split(s_val,y_val,test_size=0.2, random_state=0)

# %%
clf = KMeans(n_clusters=8,init='k-means++',n_init=10,max_iter=300,n_jobs=10)

# %%
clf.fit(X_trn)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=10, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# label mapping

# %%
y_pre=clf.predict(s_val)
# Out:
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)

# %%
print(np.unique(y_pre))
print(np.unique(y_val))
# Out:
# [0 1 2 3 4 5 6 7]
# [0 1 3 4 5 6 8 9]

# %%
#https://blog.csdn.net/u013927464/article/details/82953854
def best_map(L1,L2):
	#L1 should be the labels and L2 should be the clustering number we got
    lab_mapdict={}
    Label1 = np.unique(L1)       # 去除重复的元素，由小大大排列
    nClass1 = len(Label1)        # 标签的大小
    Label2 = np.unique(L2)       
    nClass2 = len(Label2)
    nClass = np.maximum(nClass1,nClass2)
    G = np.zeros((nClass,nClass))
    for i in range(nClass1):
        ind_cla1 = L1 == Label1[i]
        ind_cla1 = ind_cla1.astype(float)
        for j in range(nClass2):
            ind_cla2 = L2 == Label2[j]
            ind_cla2 = ind_cla2.astype(float)
            G[i,j] = np.sum(ind_cla2 * ind_cla1)
    m = Munkres()
    index = m.compute(-G.T)
    index = np.array(index)
    print('Mapping Index:',index)
    c = index[:,1]
    newL2 = np.zeros(L2.shape)
    for i in range(nClass2):
        newL2[L2 == Label2[i]] = Label1[c[i]]
        lab_mapdict[Label2[index[i,0]]]=Label1[index[i,1]]
    return lab_mapdict,newL2

# %%
lab_mapdict,newL2=best_map(y_val,y_pre)
# Out:
# Mapping Index: [[0 6]
#  [1 1]
#  [2 5]
#  [3 3]
#  [4 4]
#  [5 0]
#  [6 7]
#  [7 2]]

# %%
print('label mapping rule:',lab_mapdict)
# Out:
# label mapping rule: {0: 8, 1: 1, 2: 6, 3: 4, 4: 5, 5: 0, 6: 9, 7: 3}

# %% [markdown]
# saving

# %%
from sklearn.externals import joblib

# %%
joblib.dump(clf,'kmeans_val_original.pkl')
# Out:
# ['kmeans_val_original_olys1.pkl']

# %% [markdown]
# ## Predicting

# %%
hex_color_dict={10:'000000',0:'009900',1:'c6b044',2:'fbff13',3:'b6ff05',4:'27ff87',5:'c24f44',
                    6:'a5a5a5',7:'69fff8',8:'f9ffa4',9:'1c0dff'}

def Hex_to_RGB(str):
    r = int(str[0:2],16)
    g = int(str[2:4],16)
    b = int(str[4:6],16)
    return [r,g,b]

def DrawResult(labels, row, col):
    num_class = 10

    X_result = np.zeros((labels.shape[0], 3))
    for i in range(num_class):
        X_result[np.where(labels == i), 0] = Hex_to_RGB(hex_color_dict[i])[0]
        X_result[np.where(labels == i), 1] = Hex_to_RGB(hex_color_dict[i])[1]
        X_result[np.where(labels == i), 2] = Hex_to_RGB(hex_color_dict[i])[2]

    X_result = np.reshape(X_result, (row, col, 3))

    return X_result

def Cal_INDEX(x):

    x=x.astype('float')

    x[x>10000]=10000
    x[x<0]=0

    R = x[:, :, 3]
    G = x[:, :, 2]
    Nir = x[:, :, 7]  # TM4
    Mir = x[:, :, 10]  # TM5
    SWir= x[:,:,11]

    NDWI = (G - Nir) / (G + Nir)
    NDVI = (Nir - R) / (Nir + R)
    NDSI = (Mir-Nir) / (Mir+Nir)
    NBI = R * SWir / Nir

    return NDWI,NDVI, NDSI, NBI

class Evaluator(object):
    def __init__(self, num_class):
        self.num_class = num_class
        self.confusion_matrix = np.zeros((self.num_class,)*2)
        # matrix shape(num_class, num_class) with elements 0 in our match. it will be 4*4

    def Kappa(self):        
        
        xsum = np.sum(self.confusion_matrix, axis=1)  # sum by row
        ysum = np.sum(self.confusion_matrix, axis=0)  # sum by column
       
        Pe = np.sum(ysum*xsum)*1.0/(self.confusion_matrix.sum()**2)
        P0 = np.diag(self.confusion_matrix).sum() / self.confusion_matrix.sum()  # predict right / all the data
        cohens_coefficient = (P0-Pe)/(1-Pe)

        return cohens_coefficient
            
    def ProducerA(self):
        #
        return np.diag(self.confusion_matrix) / np.sum(self.confusion_matrix, axis=1)

    def UserA(self):
        #
        return np.diag(self.confusion_matrix) / np.sum(self.confusion_matrix, axis=0)


    def Pixel_Accuracy(self):
        Acc = np.diag(self.confusion_matrix).sum() / self.confusion_matrix.sum()
        return Acc

    def val_Pixel_Accuracy_Class(self):
        Acc = np.diag(self.confusion_matrix) / self.confusion_matrix.sum(axis=1)
        # each pred right class is in diag. sum by row is the count of corresponding class
#         index=np.array([0,1])
#         Acc=Acc[index]
        #Acc[-1]=90
        Acc = np.nanmean(Acc) #
        return Acc

    def pre_Pixel_Accuracy_Class(self):
        Acc = np.diag(self.confusion_matrix) / self.confusion_matrix.sum(axis=1)
        # each pred right class is in diag. sum by row is the count of corresponding class
#         index=np.array([0,1])
#         Acc=Acc[index]
        #Acc[-1]=90
        Acc = np.nanmean(Acc) #
        return Acc

    def Mean_Intersection_over_Union(self):
        MIoU = np.diag(self.confusion_matrix) / (
                    np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
                    np.diag(self.confusion_matrix))
        MIoU = np.nanmean(MIoU)
        return MIoU

    def Frequency_Weighted_Intersection_over_Union(self):
        freq = np.sum(self.confusion_matrix, axis=1) / np.sum(self.confusion_matrix)
        iu = np.diag(self.confusion_matrix) / (
                    np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
                    np.diag(self.confusion_matrix))

        FWIoU = (freq[freq > 0] * iu[freq > 0]).sum()
        return FWIoU

    def _generate_matrix(self, gt_image, pre_image):
        # gt_image = batch_size*256*256   pre_image = batch_size*256*256
        mask = (gt_image >= 0) & (gt_image < self.num_class)  # valid in mask show True, ignored in mask show False
        label = self.num_class * gt_image[mask].astype('int') + pre_image[mask]
        # gt_image[mask] : find out valid pixels. elements with 0,1,2,3 , so label range in  0-15
        count = np.bincount(label, minlength=self.num_class**2)
        # [0, 1, 2, 3,  confusion_matrix like this:
        #  4, 5, 6, 7,  and if the element is on the diagonal, it means predict the right class.
        #  8, 9, 10,11, row means the real label, column means pred label
        #  12,13,14,15]
        # return a array [a,b....], each letters holds the count of a class and map to class0, class1...
        confusion_matrix = count.reshape(self.num_class, self.num_class)
        return confusion_matrix

    def add_batch(self, gt_image, pre_image):
        assert gt_image.shape == pre_image.shape
        self.confusion_matrix += self._generate_matrix(gt_image, pre_image)

    def reset(self):
        self.confusion_matrix = np.zeros((self.num_class,) * 2)

# %%
from scipy.misc import imsave
from PIL import Image

# %%
base_dir = '/data/PublicData/DF2020/val/'
s1_pre, s2_pre, lc_pre=load_data(base_dir)
# Out:
# 100%|██████████| 986/986 [00:00<00:00, 388062.66it/s]

# %% [markdown]
# load model

# %%
clf=joblib.load('kmeans_val_original.pkl')

# %%
evaluator=Evaluator(10)
main_dir='/data/di.wang/ordinary/23DCNN/DataFusion_2020_new/preval/kmeans_origina/'

outputdir=main_dir+'output/'
visdir=main_dir+'vis/'

if not os.path.exists(outputdir):
    os.makedirs(outputdir)

if not os.path.exists(visdir):
    os.makedirs(visdir)

# %%
for i in tqdm(range(s1_pre.shape[0])):
    s1_name=s1_pre[i]
    s2_name=s2_pre[i]
    y_name=lc_pre[i]
    x1,x2=read_data(s1_name,s2_name)
    x1=x1.transpose(1,2,0)#h,w,c
    x2=x2.transpose(1,2,0)
    x2_tmp=x2.copy()
    x2=x2[:,:,[1,2,3,4,5,6,7,10,11,12]]#remove b1,9,10
    
    x1,x2=clean(x1,x2)
    
    with rasterio.open(y_name) as patch:
        y = patch.read(list(range(1, 5)))
    y = process_label(y)
    y = filter_label(x2_tmp, y)
    x1, x2 = norm(x1, x2)
    
    x1=x1.reshape(-1,2)
    x2=x2.reshape(-1,10)
    #x=np.concatenate((x1,x2),axis=1)
    
    y_pre=clf.predict(x)
    
    # postprocessing
    NDWI,NDVI,NDSI,NBI=Cal_INDEX(x2_tmp)
    
    y_pre=list(map(lambda x:lab_mapdict[x],y_pre))
    
    y_pre=np.array(y_pre).reshape(256,256)
    
    im = np.uint8(y_pre + 1)
    
    # wetland
    
#     im[np.where((NDVI>0.6) & (NDVI<0.75)& (im==4) &(np.sum(im==10)>10000))]=5
#     y_pre[np.where((NDVI>0.6) & (NDVI<0.75)&(y_pre==3) &(np.sum(y_pre==9)>10000))]=4
    
    evaluator.add_batch(y, y_pre[np.newaxis, :, :])
    
    filename=os.path.basename(y_name)
    former = filename.split('lc')[0]
    latter = filename.split('lc')[1]
    
    imsave(outputdir+former+'dfc'+latter,im)
    im_rgb = Image.fromarray(np.uint8(DrawResult(y_pre.reshape(-1), 256, 256)))
    im_rgb.save(visdir + former+'dfc'+latter[:-4] + '_vis.png')
# Out:
#   0%|          | 0/986 [00:00<?, ?it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   0%|          | 1/986 [00:00<07:14,  2.27it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   0%|          | 2/986 [00:00<06:41,  2.45it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   0%|          | 3/986 [00:01<06:08,  2.67it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   0%|          | 4/986 [00:01<05:47,  2.82it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|          | 5/986 [00:01<05:49,  2.81it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|          | 6/986 [00:02<05:29,  2.98it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|          | 7/986 [00:02<05:05,  3.21it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|          | 8/986 [00:02<05:00,  3.26it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|          | 9/986 [00:02<04:51,  3.35it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|          | 10/986 [00:03<04:33,  3.57it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|          | 11/986 [00:03<04:17,  3.79it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|          | 12/986 [00:03<04:19,  3.75it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|▏         | 13/986 [00:03<04:23,  3.69it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   1%|▏         | 14/986 [00:04<04:29,  3.60it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 15/986 [00:04<04:33,  3.55it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 16/986 [00:04<04:33,  3.54it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 17/986 [00:05<04:29,  3.60it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 18/986 [00:05<04:34,  3.52it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 19/986 [00:05<04:43,  3.41it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 20/986 [00:05<04:49,  3.34it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 21/986 [00:06<04:49,  3.34it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 22/986 [00:06<04:44,  3.38it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 23/986 [00:06<04:33,  3.52it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   2%|▏         | 24/986 [00:07<04:31,  3.54it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 25/986 [00:07<04:27,  3.59it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 26/986 [00:07<04:37,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 27/986 [00:07<04:37,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 28/986 [00:08<04:42,  3.39it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 29/986 [00:08<04:47,  3.33it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 30/986 [00:08<04:40,  3.41it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 31/986 [00:09<04:36,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 32/986 [00:09<04:37,  3.44it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 33/986 [00:09<04:39,  3.42it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   3%|▎         | 34/986 [00:10<04:44,  3.35it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▎         | 35/986 [00:10<04:51,  3.27it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▎         | 36/986 [00:10<04:43,  3.36it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▍         | 37/986 [00:10<04:48,  3.29it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▍         | 38/986 [00:11<04:45,  3.32it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▍         | 39/986 [00:11<04:39,  3.38it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▍         | 40/986 [00:11<04:37,  3.41it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▍         | 41/986 [00:12<04:34,  3.44it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▍         | 42/986 [00:12<04:30,  3.49it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▍         | 43/986 [00:12<04:28,  3.51it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   4%|▍         | 44/986 [00:12<04:27,  3.52it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▍         | 45/986 [00:13<04:39,  3.37it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▍         | 46/986 [00:13<04:42,  3.33it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▍         | 47/986 [00:13<04:49,  3.25it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▍         | 48/986 [00:14<04:43,  3.31it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▍         | 49/986 [00:14<04:33,  3.42it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▌         | 50/986 [00:14<04:32,  3.44it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▌         | 51/986 [00:15<04:29,  3.47it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▌         | 52/986 [00:15<04:27,  3.50it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▌         | 53/986 [00:15<04:27,  3.48it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   5%|▌         | 54/986 [00:15<04:34,  3.39it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▌         | 55/986 [00:16<04:40,  3.32it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▌         | 56/986 [00:16<04:42,  3.29it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▌         | 57/986 [00:16<04:56,  3.13it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▌         | 58/986 [00:17<04:51,  3.19it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▌         | 59/986 [00:17<04:47,  3.22it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▌         | 60/986 [00:17<04:34,  3.37it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▌         | 61/986 [00:18<04:31,  3.41it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▋         | 62/986 [00:18<04:41,  3.28it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▋         | 63/986 [00:18<04:45,  3.24it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   6%|▋         | 64/986 [00:18<04:40,  3.29it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   7%|▋         | 65/986 [00:19<04:35,  3.35it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   7%|▋         | 66/986 [00:19<04:32,  3.38it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   7%|▋         | 67/986 [00:19<04:28,  3.42it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   7%|▋         | 68/986 [00:20<04:51,  3.15it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   7%|▋         | 69/986 [00:20<04:45,  3.22it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   7%|▋         | 70/986 [00:20<04:47,  3.19it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   7%|▋         | 71/986 [00:21<04:47,  3.18it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   7%|▋         | 72/986 [00:21<04:38,  3.29it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   7%|▋         | 73/986 [00:21<04:31,  3.37it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 74/986 [00:21<04:24,  3.45it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 75/986 [00:22<04:20,  3.49it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 76/986 [00:22<04:18,  3.52it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 77/986 [00:22<04:30,  3.36it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 78/986 [00:23<04:32,  3.33it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 79/986 [00:23<04:30,  3.35it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 80/986 [00:23<04:29,  3.36it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 81/986 [00:24<04:25,  3.41it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 82/986 [00:24<04:23,  3.43it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   8%|▊         | 83/986 [00:24<04:23,  3.43it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▊         | 84/986 [00:24<04:19,  3.48it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▊         | 85/986 [00:25<04:22,  3.44it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▊         | 86/986 [00:25<04:32,  3.30it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▉         | 87/986 [00:25<04:42,  3.19it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▉         | 88/986 [00:26<04:51,  3.09it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▉         | 89/986 [00:26<04:43,  3.17it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▉         | 90/986 [00:26<04:37,  3.23it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▉         | 91/986 [00:27<04:27,  3.35it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▉         | 92/986 [00:27<04:23,  3.39it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   9%|▉         | 93/986 [00:27<04:36,  3.23it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|▉         | 94/986 [00:27<04:26,  3.35it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|▉         | 95/986 [00:28<04:43,  3.15it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|▉         | 96/986 [00:28<04:38,  3.20it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|▉         | 97/986 [00:28<04:41,  3.16it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|▉         | 98/986 [00:29<04:41,  3.15it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|█         | 99/986 [00:29<04:19,  3.42it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|█         | 100/986 [00:29<04:16,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|█         | 101/986 [00:30<04:14,  3.47it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|█         | 102/986 [00:30<04:13,  3.49it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  10%|█         | 103/986 [00:30<04:23,  3.36it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█         | 104/986 [00:31<04:28,  3.29it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█         | 105/986 [00:31<04:44,  3.09it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█         | 106/986 [00:31<04:45,  3.08it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█         | 107/986 [00:32<04:49,  3.04it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█         | 108/986 [00:32<04:54,  2.98it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█         | 109/986 [00:32<04:36,  3.17it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█         | 110/986 [00:32<04:22,  3.34it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█▏        | 111/986 [00:33<04:20,  3.36it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█▏        | 112/986 [00:33<04:10,  3.49it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  11%|█▏        | 113/986 [00:33<04:16,  3.41it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 114/986 [00:34<04:06,  3.54it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 115/986 [00:34<04:09,  3.50it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 116/986 [00:34<04:06,  3.53it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 117/986 [00:34<04:06,  3.52it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 118/986 [00:35<04:06,  3.53it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 119/986 [00:35<04:10,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 120/986 [00:35<04:09,  3.47it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 121/986 [00:36<04:09,  3.47it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 122/986 [00:36<04:12,  3.43it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  12%|█▏        | 123/986 [00:36<04:27,  3.23it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 124/986 [00:37<04:24,  3.26it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 125/986 [00:37<04:13,  3.39it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 126/986 [00:37<04:12,  3.41it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 127/986 [00:37<04:08,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 128/986 [00:38<04:05,  3.49it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 129/986 [00:38<04:04,  3.51it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 130/986 [00:38<04:09,  3.43it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 131/986 [00:39<04:07,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 132/986 [00:39<04:09,  3.42it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  13%|█▎        | 133/986 [00:39<04:10,  3.40it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  14%|█▎        | 134/986 [00:39<04:06,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  14%|█▎        | 135/986 [00:40<04:20,  3.27it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  14%|█▍        | 136/986 [00:40<04:26,  3.19it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  14%|█▍        | 137/986 [00:40<04:29,  3.16it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  14%|█▍        | 138/986 [00:41<04:24,  3.21it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  14%|█▍        | 139/986 [00:41<04:20,  3.26it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  14%|█▍        | 140/986 [00:41<04:12,  3.35it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  14%|█▍        | 141/986 [00:42<04:10,  3.37it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  14%|█▍        | 142/986 [00:42<04:06,  3.42it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▍        | 143/986 [00:42<04:02,  3.47it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▍        | 144/986 [00:42<04:01,  3.48it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▍        | 145/986 [00:43<04:01,  3.49it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▍        | 146/986 [00:43<04:00,  3.50it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▍        | 147/986 [00:43<04:02,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▌        | 148/986 [00:44<04:01,  3.46it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▌        | 149/986 [00:44<03:59,  3.49it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▌        | 150/986 [00:44<03:57,  3.51it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▌        | 151/986 [00:44<04:04,  3.41it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  15%|█▌        | 152/986 [00:45<04:14,  3.28it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  16%|█▌        | 153/986 [00:45<04:28,  3.10it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  16%|█▌        | 154/986 [00:45<04:14,  3.27it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  16%|█▌        | 155/986 [00:46<04:09,  3.33it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  16%|█▌        | 156/986 [00:46<04:04,  3.39it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  16%|█▌        | 157/986 [00:46<04:01,  3.43it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  16%|█▌        | 158/986 [00:47<03:57,  3.48it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  16%|█▌        | 159/986 [00:47<03:58,  3.47it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  16%|█▌        | 160/986 [00:47<03:55,  3.51it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  16%|█▋        | 161/986 [00:47<03:54,  3.52it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# ...
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  94%|█████████▍| 931/986 [04:11<00:14,  3.67it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▍| 932/986 [04:11<00:14,  3.74it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▍| 933/986 [04:12<00:14,  3.74it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▍| 934/986 [04:12<00:13,  3.98it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▍| 935/986 [04:12<00:12,  4.13it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▍| 936/986 [04:12<00:12,  4.07it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▌| 937/986 [04:13<00:12,  4.07it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▌| 938/986 [04:13<00:11,  4.17it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▌| 939/986 [04:13<00:11,  4.17it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▌| 940/986 [04:13<00:10,  4.30it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  95%|█████████▌| 941/986 [04:13<00:10,  4.39it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▌| 942/986 [04:14<00:09,  4.41it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▌| 943/986 [04:14<00:10,  4.23it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▌| 944/986 [04:14<00:09,  4.21it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▌| 945/986 [04:14<00:09,  4.21it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▌| 946/986 [04:15<00:09,  4.01it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▌| 947/986 [04:15<00:09,  4.12it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▌| 948/986 [04:15<00:09,  4.13it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▌| 949/986 [04:15<00:09,  3.96it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▋| 950/986 [04:16<00:09,  3.87it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  96%|█████████▋| 951/986 [04:16<00:08,  3.91it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 952/986 [04:16<00:08,  3.83it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 953/986 [04:16<00:08,  3.89it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 954/986 [04:17<00:08,  3.93it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 955/986 [04:17<00:07,  4.06it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 956/986 [04:17<00:07,  3.94it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 957/986 [04:17<00:07,  4.12it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 958/986 [04:18<00:06,  4.24it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 959/986 [04:18<00:06,  4.14it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 960/986 [04:18<00:06,  4.22it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  97%|█████████▋| 961/986 [04:18<00:05,  4.30it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 962/986 [04:19<00:05,  4.35it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 963/986 [04:19<00:05,  4.27it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 964/986 [04:19<00:05,  4.34it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 965/986 [04:19<00:04,  4.21it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 966/986 [04:20<00:04,  4.11it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 967/986 [04:20<00:04,  4.22it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 968/986 [04:20<00:04,  4.16it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 969/986 [04:20<00:04,  4.23it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 970/986 [04:20<00:03,  4.27it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  98%|█████████▊| 971/986 [04:21<00:03,  4.15it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▊| 972/986 [04:21<00:03,  4.21it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▊| 973/986 [04:21<00:03,  4.05it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▉| 974/986 [04:21<00:02,  4.11it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▉| 975/986 [04:22<00:02,  4.05it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▉| 976/986 [04:22<00:02,  4.13it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▉| 977/986 [04:22<00:02,  3.98it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▉| 978/986 [04:22<00:01,  4.06it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▉| 979/986 [04:23<00:01,  3.82it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▉| 980/986 [04:23<00:01,  3.81it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#  99%|█████████▉| 981/986 [04:23<00:01,  3.95it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# 100%|█████████▉| 982/986 [04:24<00:01,  3.98it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# 100%|█████████▉| 983/986 [04:24<00:00,  3.97it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# 100%|█████████▉| 984/986 [04:24<00:00,  3.85it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# 100%|█████████▉| 985/986 [04:24<00:00,  3.81it/s]/data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# 100%|██████████| 986/986 [04:25<00:00,  3.72it/s]

# %%
AA = evaluator.pre_Pixel_Accuracy_Class()

print('AVERAGE ACCURACY of val DATASET: {}'.format(AA))

print('CONFUSION MATRIX')

print(evaluator.confusion_matrix)

print('ACCURACY IN EACH CLASSES:',np.diag(evaluator.confusion_matrix) / evaluator.confusion_matrix.sum(axis=1))

print('Prediction finished!')
# Out:
# AVERAGE ACCURACY of val DATASET: 0.4833371200874479
# CONFUSION MATRIX
# [[2.742586e+06 0.000000e+00 0.000000e+00 8.700000e+01 3.168800e+04
#   0.000000e+00 1.540000e+02 0.000000e+00 0.000000e+00 1.900000e+01]
#  [1.100000e+01 1.044000e+03 0.000000e+00 5.212480e+05 4.470000e+02
#   8.682700e+04 1.819300e+04 0.000000e+00 1.220000e+02 9.867000e+03]
#  [0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#   0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00]
#  [3.808600e+04 5.130000e+03 0.000000e+00 1.116699e+06 1.343280e+05
#   3.818790e+05 4.030790e+05 0.000000e+00 3.201000e+03 5.071300e+04]
#  [4.155460e+05 8.530000e+02 0.000000e+00 3.495200e+04 1.498349e+06
#   3.941000e+03 9.999000e+03 0.000000e+00 1.200000e+03 2.771000e+03]
#  [4.816100e+04 1.340000e+02 0.000000e+00 6.373690e+05 5.224100e+04
#   2.508827e+06 1.638620e+05 0.000000e+00 4.020000e+02 2.386000e+03]
#  [6.636400e+04 8.800000e+01 0.000000e+00 5.336090e+05 3.968700e+04
#   2.317710e+05 7.507360e+05 0.000000e+00 5.920000e+02 2.838000e+03]
#  [0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#   0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00]
#  [2.260000e+02 9.570000e+02 0.000000e+00 1.107230e+05 3.880000e+02
#   1.436970e+05 8.227900e+04 0.000000e+00 6.240000e+02 1.351800e+04]
#  [5.162000e+03 4.504011e+06 0.000000e+00 5.205200e+04 2.238800e+04
#   1.821800e+04 9.284000e+03 0.000000e+00 7.546534e+06 7.871326e+06]]
# ACCURACY IN EACH CLASSES: [0.98848527 0.00163698        nan 0.52350623 0.76150672 0.73499743
#  0.46179672        nan 0.00177065 0.39299695]
# Prediction finished!
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# /data/di.wang/.conda/envs/pytorch/lib/python3.5/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':
